# %%
pip install opencv-python mediapipe
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.10.0.84)
# Requirement already satisfied: mediapipe in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.10.14)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: absl-py in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: jaxlib in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (4.25.5)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jax->mediapipe) (0.5.0)
# Requirement already satisfied: opt-einsum in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jax->mediapipe) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import mediapipe as mp
import time  


mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_drawing = mp.solutions.drawing_utils


keys = [
    ['Q', 'W', 'E', 'R', 'T', 'Y', 'U', 'I', 'O', 'P'],
    ['A', 'S', 'D', 'F', 'G', 'H', 'J', 'K', 'L'],
    ['Z', 'X', 'C', 'V', 'B', 'N', 'M', 'SPACE', 'BACK']
]


key_width = 80
key_height = 80
spacing = 15 

output_text = ""


WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
BLUE = (255, 0, 0)

last_tap_time = 0 
tap_delay = 1  

def draw_keyboard(img):
    rows = len(keys)
    max_row_length = max(len(row) for row in keys)

   
    frame_h, frame_w, _ = img.shape
    total_keyboard_width = max_row_length * (key_width + spacing) - spacing
    start_x = (frame_w - total_keyboard_width) // 2  
    start_y = frame_h - (rows * (key_height + spacing) + 100) 


    for i, row in enumerate(keys):
        for j, key in enumerate(row):
            key_x = start_x + j * (key_width + spacing)
            key_y = start_y + i * (key_height + spacing)

           
            cv2.rectangle(img, (key_x, key_y), (key_x + key_width, key_y + key_height), WHITE, -1)
            cv2.putText(img, key, (key_x + 20, key_y + 50), cv2.FONT_HERSHEY_SIMPLEX, 1, BLACK, 2)


def detect_tap(landmarks, img):
    global output_text, last_tap_time
    current_time = time.time()  

    if landmarks:
        frame_h, frame_w, _ = img.shape
        max_row_length = max(len(row) for row in keys)

        for id, lm in enumerate(landmarks.landmark):
            cx, cy = int(lm.x * frame_w), int(lm.y * frame_h)

    
            if id == 8:  # Index finger tip
                for i, row in enumerate(keys):
                    for j, key in enumerate(row):
                        key_x = (frame_w // 2 - (max_row_length * (key_width + spacing) - spacing) // 2) + j * (key_width + spacing)
                        key_y = frame_h - (len(keys) * (key_height + spacing) + 100) + i * (key_height + spacing)

                
                        if key_x <= cx <= key_x + key_width and key_y <= cy <= key_y + key_height:
                            
                            if current_time - last_tap_time >= tap_delay:
                                handle_keypress(key)
                                last_tap_time = current_time  


def handle_keypress(key):
    global output_text
    if key == 'SPACE':
        output_text += ' '
    elif key == 'BACK':
        output_text = output_text[:-1]
    else:
        output_text += key
    print("Typed Text:", output_text)


def draw_output_text(img):
    cv2.putText(img, output_text, (50, 350), cv2.FONT_HERSHEY_SIMPLEX, 2, BLUE, 3)

def main():
    global output_text

 
    cap = cv2.VideoCapture(0)

    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame.")
            break

 
        frame = cv2.flip(frame, 1)

        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        results = hands.process(img_rgb)

        
        draw_keyboard(frame)

     
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
                detect_tap(hand_landmarks, frame)

        
        draw_output_text(frame)

       
        cv2.imshow("Virtual Keyboard", frame)

 
        if cv2.waitKey(1) & 0xFF == 27:
            break

    cap.release()
    cv2.destroyAllWindows()


if __name__ == "__main__":
    main()
# Out:
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Typed Text: E
# Typed Text: ER
# Typed Text: ERE
# Typed Text: ERES
# Typed Text: ERESW
# Typed Text: ERESWQ
# Typed Text: ERESWQW
# Typed Text: ERESWQWE
# Typed Text: ERESWQWES
# Typed Text: ERESWQWESW
# Typed Text: ERESWQWESWE
# Typed Text: ERESWQWESWER
# Typed Text: ERESWQWESWERU
# Typed Text: ERESWQWESWER
# Typed Text: ERESWQWESWE
# Typed Text: ERESWQWESW
# Typed Text: ERESWQWES
# Typed Text: ERESWQWE
# Typed Text: ERESWQW
# Typed Text: ERESWQ
# Typed Text: ERESW
# Typed Text: ERES
# Typed Text: ERE
# Typed Text: ER
# Typed Text: E
# Typed Text:
# Typed Text: P
# Typed Text: PD
# Typed Text: PD
# Typed Text: PD
# Typed Text: PD
# Typed Text: PD
# Typed Text: P
# Typed Text: PA
# Typed Text: PAG
# Typed Text: PAGN
# Typed Text: PAGN
# Typed Text: PAGN
# Typed Text: PAG
# Typed Text: PAG
# Typed Text: PAG
# Typed Text: PA
# Typed Text: PAM
# Typed Text: PAMM
# Typed Text: PAMM
# Typed Text: PAMM
# Typed Text: PAMM
# Typed Text: PAMM
# Typed Text: PAMM
# Typed Text: PAMM
# Typed Text: PAMMK
# Typed Text: PAMM
# Typed Text: PAM
# Typed Text: PA
# Typed Text: PAM
# Typed Text: PAMN
# Typed Text: PAMN
# Typed Text: PAMN
# Typed Text: PAM
# Typed Text: PAM
# Typed Text: PAM
# Typed Text: PAM
# Typed Text: PAM
# Typed Text: PAM
# Typed Text: PAM
# Typed Text: PAM
# Typed Text: PAM
# Typed Text: PA
# Typed Text: PAN
# Typed Text: PANC
# Typed Text: PANCN
# Typed Text: PANCNH
# Typed Text: PANCNHN
# Typed Text: PANCNHN
# Typed Text: PANCNHN
# Typed Text: PANCNHN
# Typed Text: PANCNHN
# Typed Text: PANCNH
# Typed Text: PANCN
# Typed Text: PANC
# Typed Text: PANCN
# Typed Text: PANCN
# Typed Text: PANCN
# Typed Text: PANC
# Typed Text: PANCY
# Typed Text: PANCYH
# Typed Text: PANCYH
# Typed Text: PANCYH
# Typed Text: PANCY
# Typed Text: PANCY
# Typed Text: PANCY
# Typed Text: PANCY
# Typed Text: PANCY
# Typed Text: PANCY
# Typed Text: PANCY
# Typed Text: PANCY
# Typed Text: PANCY V
# Typed Text: PANCY V
# Typed Text: PANCY V
# Typed Text: PANCY V
# Typed Text: PANCY V
# Typed Text: PANCY V
# Typed Text: PANCY V
# Typed Text: PANCY
# Typed Text: PANCY
# Typed Text: PANC
# Typed Text: PANCB
# Typed Text: PANCBH
# Typed Text: PANCBHM
# Typed Text: PANCBHM
# Typed Text: PANCBHM
# Typed Text: PANCBH
# Typed Text: PANCB
# Typed Text: PANC
# Typed Text: PANCM
# Typed Text: PANCMH
# Typed Text: PANCMH
# Typed Text: PANCMH
# Typed Text: PANCMH
# Typed Text: PANCMH
# Typed Text: PANCMH
# Typed Text: PANCMH
# Typed Text: PANCM
# Typed Text: PANC
# Typed Text: PANCB
# Typed Text: PANCBH
# Typed Text: PANCBH
# Typed Text: PANCBH
# Typed Text: PANCBH
# Typed Text: PANCBH
# Typed Text: PANCBH
# Typed Text: PANCBH
# Typed Text: PANCBH
# Typed Text: PANCBH
# Typed Text: PANCB
# Typed Text: PANC
# Typed Text: PANCM
# Typed Text: PANCMJ
# Typed Text: PANCMJ
# Typed Text: PANCMJ
# Typed Text: PANCM
# Typed Text: PANC
# Typed Text: PANCG
# Typed Text: PANCGH
# Typed Text: PANCG
# Typed Text: PANC
# Typed Text: PANCM
# Typed Text: PANC
# Typed Text: PANCL
# Typed Text: PANC
# Typed Text: PAN
# Typed Text: PANC
# Typed Text: PANCH
# Typed Text: PANCHC
# Typed Text: PANCHCX
# Typed Text: PANCHCXA
# Typed Text: PANCHCXAB
# Typed Text: PANCHCXA
# Typed Text: PANCHCX
# Typed Text: PANCHC
# Typed Text: PANCH
# Typed Text: PANCHZ
# Typed Text: PANCHZM
# Typed Text: PANCHZ
# Typed Text: PANCH
# Typed Text: PANCHZ
# Typed Text: PANCHZZ
# Typed Text: PANCHZ
# Typed Text: PANCH
# Typed Text: PANC
# Typed Text: PANCH
# Typed Text: PANCHA
# Typed Text: PANCHAF
# Typed Text: PANCHAFF
# Typed Text: PANCHAFFN
# Typed Text: PANCHAFF
# Typed Text: PANCHAF
# Typed Text: PANCHAFM
# Typed Text: PANCHAF
# Typed Text: PANCHA
# Typed Text: PANCHAF
# Typed Text: PANCHAFM
# Typed Text: PANCHAF
# Typed Text: PANCHA
# Typed Text: PANCHAV
# Typed Text: PANCHAVM
# Typed Text: PANCHAV
# Typed Text: PANCHA
# Typed Text: PANCHAD
# Typed Text: PANCHADN
# Typed Text: PANCHADNK
# Typed Text: PANCHADNKK
# Typed Text: PANCHADNK
# Typed Text: PANCHADN
# Typed Text: PANCHAD
# Typed Text: PANCHADU
# Typed Text: PANCHADU
# Typed Text: PANCHADU
# Typed Text: PANCHAD
# Typed Text: PANCHADU
# Typed Text: PANCHADUI
# Typed Text: PANCHADU
# Typed Text: PANCHAD
# Typed Text: PANCHADI
# Typed Text: PANCHADIL
# Typed Text: PANCHADILL
# Typed Text: PANCHADIL
# Typed Text: PANCHADI
# Typed Text: PANCHADIP
# Typed Text: PANCHADIPM
# Typed Text: PANCHADIPM
# Typed Text: PANCHADIPM
# Typed Text: PANCHADIP
# Typed Text: PANCHADIP
# Typed Text: PANCHADIP
# Typed Text: PANCHADIP  N
# Typed Text: PANCHADIP  N
# Typed Text: PANCHADIP  N
# Typed Text: PANCHADIP
# Typed Text: PANCHADIP  N
# Typed Text: PANCHADIP  N
# Typed Text: PANCHADIP  N
# Typed Text: PANCHADIP
# Typed Text: PANCHADIP
# Typed Text: PANCHADIP   B
# Typed Text: PANCHADIP   BH
# Typed Text: PANCHADIP   BHV
# Typed Text: PANCHADIP   BHVM
# Typed Text: PANCHADIP   BHV
# Typed Text: PANCHADIP   BH
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHAYT
# Typed Text: PANCHADIP   BHAYT
# Typed Text: PANCHADIP   BHAYT
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAT
# Typed Text: PANCHADIP   BHATY
# Typed Text: PANCHADIP   BHATYT
# Typed Text: PANCHADIP   BHATYT
# Typed Text: PANCHADIP   BHATYT
# Typed Text: PANCHADIP   BHATY
# Typed Text: PANCHADIP   BHAT
# Typed Text: PANCHADIP   BHATT
# Typed Text: PANCHADIP   BHATTX
# Typed Text: PANCHADIP   BHATTX
# Typed Text: PANCHADIP   BHATTX
# Typed Text: PANCHADIP   BHATTX
# Typed Text: PANCHADIP   BHATTX
# Typed Text: PANCHADIP   BHATTX
# Typed Text: PANCHADIP   BHATTX
# Typed Text: PANCHADIP   BHATT
# Typed Text: PANCHADIP   BHAT
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BH
# Typed Text: PANCHADIP   B
# Typed Text: PANCHADIP   BM
# Typed Text: PANCHADIP   BMH
# Typed Text: PANCHADIP   BMH
# Typed Text: PANCHADIP   BMH
# Typed Text: PANCHADIP   BM
# Typed Text: PANCHADIP   BM
# Typed Text: PANCHADIP   BM
# Typed Text: PANCHADIP   BM
# Typed Text: PANCHADIP   BM
# Typed Text: PANCHADIP   BM
# Typed Text: PANCHADIP   BM
# Typed Text: PANCHADIP   B
# Typed Text: PANCHADIP   BH
# Typed Text: PANCHADIP   BHX
# Typed Text: PANCHADIP   BHXX
# Typed Text: PANCHADIP   BHXX
# Typed Text: PANCHADIP   BHXX
# Typed Text: PANCHADIP   BHX
# Typed Text: PANCHADIP   BH
# Typed Text: PANCHADIP   BHZ
# Typed Text: PANCHADIP   BH
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAR
# Typed Text: PANCHADIP   BHART
# Typed Text: PANCHADIP   BHAR
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAG
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAG
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAG
# Typed Text: PANCHADIP   BHAG
# Typed Text: PANCHADIP   BHAG
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAF
# Typed Text: PANCHADIP   BHAFM
# Typed Text: PANCHADIP   BHAF
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAH
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAH
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAY
# Typed Text: PANCHADIP   BHA
# Typed Text: PANCHADIP   BHAT
# Typed Text: PANCHADIP   BHATT
# Typed Text: PANCHADIP   BHATTV
# Typed Text: PANCHADIP   BHATTVA
# Typed Text: PANCHADIP   BHATTVAR
# Typed Text: PANCHADIP   BHATTVAR
# Typed Text: PANCHADIP   BHATTVAR
# Typed Text: PANCHADIP   BHATTVA
# Typed Text: PANCHADIP   BHATTV
# Typed Text: PANCHADIP   BHATT
# Typed Text: PANCHADIP   BHATTD
# Typed Text: PANCHADIP   BHATTDJ
# Typed Text: PANCHADIP   BHATTD
# Typed Text: PANCHADIP   BHATT
# Typed Text: PANCHADIP   BHATTZ
# Typed Text: PANCHADIP   BHATTZX
# Typed Text: PANCHADIP   BHATTZ
# Typed Text: PANCHADIP   BHATT
# Typed Text: PANCHADIP   BHATTA
# Typed Text: PANCHADIP   BHATTAC
# Typed Text: PANCHADIP   BHATTACB
# Typed Text: PANCHADIP   BHATTACBG
# Typed Text: PANCHADIP   BHATTACBGA
# Typed Text: PANCHADIP   BHATTACBGAF
# Typed Text: PANCHADIP   BHATTACBGAFG
# Typed Text: PANCHADIP   BHATTACBGAF
# Typed Text: PANCHADIP   BHATTACBGA
# Typed Text: PANCHADIP   BHATTACBG
# Typed Text: PANCHADIP   BHATTACB
# Typed Text: PANCHADIP   BHATTAC
# Typed Text: PANCHADIP   BHATTACH
# Typed Text: PANCHADIP   BHATTACHA
# Typed Text: PANCHADIP   BHATTACHAB
# Typed Text: PANCHADIP   BHATTACHABR
# Typed Text: PANCHADIP   BHATTACHABRM
# Typed Text: PANCHADIP   BHATTACHABRM
# Typed Text: PANCHADIP   BHATTACHABRM
# Typed Text: PANCHADIP   BHATTACHABR
# Typed Text: PANCHADIP   BHATTACHAB
# Typed Text: PANCHADIP   BHATTACHA
# Typed Text: PANCHADIP   BHATTACHAT
# Typed Text: PANCHADIP   BHATTACHATR
# Typed Text: PANCHADIP   BHATTACHATRR
# Typed Text: PANCHADIP   BHATTACHATRR
# Typed Text: PANCHADIP   BHATTACHATRR
# Typed Text: PANCHADIP   BHATTACHATR
# Typed Text: PANCHADIP   BHATTACHAT
# Typed Text: PANCHADIP   BHATTACHA
# Typed Text: PANCHADIP   BHATTACHAT
# Typed Text: PANCHADIP   BHATTACHA
# Typed Text: PANCHADIP   BHATTACHAR
# Typed Text: PANCHADIP   BHATTACHAR
# Typed Text: PANCHADIP   BHATTACHAR K
# Typed Text: PANCHADIP   BHATTACHAR
# Typed Text: PANCHADIP   BHATTACHAR
# Typed Text: PANCHADIP   BHATTACHARJ
# Typed Text: PANCHADIP   BHATTACHARJE
# Typed Text: PANCHADIP   BHATTACHARJEE
# Typed Text: PANCHADIP   BHATTACHARJEEV
# Typed Text: PANCHADIP   BHATTACHARJEE
